# %%
import pandas as pd
import numpy as np

import seaborn as sns 
import matplotlib.pyplot  as plt

# %%
df=pd.read_csv("penguins.csv")
df
# Out:
#     species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0    Adelie  Torgersen            39.1           18.7              181.0
# 1    Adelie  Torgersen            39.5           17.4              186.0
# 2    Adelie  Torgersen            40.3           18.0              195.0
# 3    Adelie  Torgersen             NaN            NaN                NaN
# 4    Adelie  Torgersen            36.7           19.3              193.0
# ..      ...        ...             ...            ...                ...
# 339  Gentoo     Biscoe             NaN            NaN                NaN
# 340  Gentoo     Biscoe            46.8           14.3              215.0
# 341  Gentoo     Biscoe            50.4           15.7              222.0
# 342  Gentoo     Biscoe            45.2           14.8              212.0
# 343  Gentoo     Biscoe            49.9           16.1              213.0
#
#      body_mass_g     sex
# 0         3750.0    MALE
# 1         3800.0  FEMALE
# ...

# %%
df.shape
# Out:
# (344, 7)

# %%
df.isnull().sum()
# Out:
# species               0
# island                0
# bill_length_mm        2
# bill_depth_mm         2
# flipper_length_mm     2
# body_mass_g           2
# sex                  11
# dtype: int64

# %%
sns.heatmap(df.isnull())
# Out:
# <Axes: >

# %% [markdown]
# # delete col where null values are find

# %%
#df.drop(columns=["sex"])            #not permant delete from dataset in original dataset because inplace para.is by default false

# %%
df
# Out:
#     species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0    Adelie  Torgersen            39.1           18.7              181.0
# 1    Adelie  Torgersen            39.5           17.4              186.0
# 2    Adelie  Torgersen            40.3           18.0              195.0
# 3    Adelie  Torgersen             NaN            NaN                NaN
# 4    Adelie  Torgersen            36.7           19.3              193.0
# ..      ...        ...             ...            ...                ...
# 339  Gentoo     Biscoe             NaN            NaN                NaN
# 340  Gentoo     Biscoe            46.8           14.3              215.0
# 341  Gentoo     Biscoe            50.4           15.7              222.0
# 342  Gentoo     Biscoe            45.2           14.8              212.0
# 343  Gentoo     Biscoe            49.9           16.1              213.0
#
#      body_mass_g     sex
# 0         3750.0    MALE
# 1         3800.0  FEMALE
# ...

# %%
df.drop(columns=["island"],inplace=True)
plt.show()

# %%
df
# Out:
#     species  bill_length_mm  bill_depth_mm  flipper_length_mm  body_mass_g  \
# 0    Adelie            39.1           18.7              181.0       3750.0
# 1    Adelie            39.5           17.4              186.0       3800.0
# 2    Adelie            40.3           18.0              195.0       3250.0
# 3    Adelie             NaN            NaN                NaN          NaN
# 4    Adelie            36.7           19.3              193.0       3450.0
# ..      ...             ...            ...                ...          ...
# 339  Gentoo             NaN            NaN                NaN          NaN
# 340  Gentoo            46.8           14.3              215.0       4850.0
# 341  Gentoo            50.4           15.7              222.0       5750.0
# 342  Gentoo            45.2           14.8              212.0       5200.0
# 343  Gentoo            49.9           16.1              213.0       5400.0
#
#         sex
# 0      MALE
# 1    FEMALE
# 2    FEMALE
# 3       NaN
# ...

# %% [markdown]
# # NAN  all values are drop using dropna function

# %%
 df.dropna(inplace=True) #no any  row values are null found 
df
# Out:
#     species  bill_length_mm  bill_depth_mm  flipper_length_mm  body_mass_g  \
# 0    Adelie            39.1           18.7              181.0       3750.0
# 1    Adelie            39.5           17.4              186.0       3800.0
# 2    Adelie            40.3           18.0              195.0       3250.0
# 4    Adelie            36.7           19.3              193.0       3450.0
# 5    Adelie            39.3           20.6              190.0       3650.0
# ..      ...             ...            ...                ...          ...
# 338  Gentoo            47.2           13.7              214.0       4925.0
# 340  Gentoo            46.8           14.3              215.0       4850.0
# 341  Gentoo            50.4           15.7              222.0       5750.0
# 342  Gentoo            45.2           14.8              212.0       5200.0
# 343  Gentoo            49.9           16.1              213.0       5400.0
#
#         sex
# 0      MALE
# 1    FEMALE
# 2    FEMALE
# 4    FEMALE
# ...

# %% [markdown]
# # To fill in place of null value

# %%
df.fillna(10).tail(20)
df  #10value is fill in place of null values
# Out:
#     species  bill_length_mm  bill_depth_mm  flipper_length_mm  body_mass_g  \
# 0    Adelie            39.1           18.7              181.0       3750.0
# 1    Adelie            39.5           17.4              186.0       3800.0
# 2    Adelie            40.3           18.0              195.0       3250.0
# 4    Adelie            36.7           19.3              193.0       3450.0
# 5    Adelie            39.3           20.6              190.0       3650.0
# ..      ...             ...            ...                ...          ...
# 338  Gentoo            47.2           13.7              214.0       4925.0
# 340  Gentoo            46.8           14.3              215.0       4850.0
# 341  Gentoo            50.4           15.7              222.0       5750.0
# 342  Gentoo            45.2           14.8              212.0       5200.0
# 343  Gentoo            49.9           16.1              213.0       5400.0
#
#         sex
# 0      MALE
# 1    FEMALE
# 2    FEMALE
# 4    FEMALE
# ...

# %% [markdown]
# # To fill categorical  values we prefer mode / forwar fill/ backword fill

# %%
df.fillna(method="ffill",axis=1) #axis 1 show  column wise
                                 #axxis 0 show row wise
# Out:
# C:\Users\ansar\AppData\Local\Temp\ipykernel_15424\2297822714.py:1: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df.fillna(method="ffill",axis=1) #axis 1 show  column wise
#     species bill_length_mm bill_depth_mm flipper_length_mm body_mass_g     sex
# 0    Adelie           39.1          18.7             181.0      3750.0    MALE
# 1    Adelie           39.5          17.4             186.0      3800.0  FEMALE
# 2    Adelie           40.3          18.0             195.0      3250.0  FEMALE
# 4    Adelie           36.7          19.3             193.0      3450.0  FEMALE
# 5    Adelie           39.3          20.6             190.0      3650.0    MALE
# ..      ...            ...           ...               ...         ...     ...
# 338  Gentoo           47.2          13.7             214.0      4925.0  FEMALE
# 340  Gentoo           46.8          14.3             215.0      4850.0  FEMALE
# ...

# %%
df.fillna(method="bfill")
# Out:
# C:\Users\ansar\AppData\Local\Temp\ipykernel_15424\3896554658.py:1: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df.fillna(method="bfill")
#     species  bill_length_mm  bill_depth_mm  flipper_length_mm  body_mass_g  \
# 0    Adelie            39.1           18.7              181.0       3750.0
# 1    Adelie            39.5           17.4              186.0       3800.0
# 2    Adelie            40.3           18.0              195.0       3250.0
# 4    Adelie            36.7           19.3              193.0       3450.0
# 5    Adelie            39.3           20.6              190.0       3650.0
# ..      ...             ...            ...                ...          ...
# 338  Gentoo            47.2           13.7              214.0       4925.0
# 340  Gentoo            46.8           14.3              215.0       4850.0
# ...

# %% [markdown]
# # Mode fill in place of NaN values ,It works only and only one column

# %%
df["species"].mode()
# Out:
# 0    Adelie
# Name: species, dtype: object

# %%
df["species"].mode()[0]
# Out:
# 'Adelie'

# %%
df["species"].fillna(df["species"].mode()[0])
# Out:
# 0      Adelie
# 1      Adelie
# 2      Adelie
# 4      Adelie
# 5      Adelie
#         ...
# 338    Gentoo
# 340    Gentoo
# 341    Gentoo
# 342    Gentoo
# 343    Gentoo
# Name: species, Length: 333, dtype: object

# %% [markdown]
# # But mode work at a time one col.therefore to work on whole object datatype in dataset we use loop concepts

# %%
index=df.select_dtypes(include="object").columns
for i in index:
    df[i].fillna(df[i].mode()[0])

# %%
df
# Out:
#     species  bill_length_mm  bill_depth_mm  flipper_length_mm  body_mass_g  \
# 0    Adelie            39.1           18.7              181.0       3750.0
# 1    Adelie            39.5           17.4              186.0       3800.0
# 2    Adelie            40.3           18.0              195.0       3250.0
# 4    Adelie            36.7           19.3              193.0       3450.0
# 5    Adelie            39.3           20.6              190.0       3650.0
# ..      ...             ...            ...                ...          ...
# 338  Gentoo            47.2           13.7              214.0       4925.0
# 340  Gentoo            46.8           14.3              215.0       4850.0
# 341  Gentoo            50.4           15.7              222.0       5750.0
# 342  Gentoo            45.2           14.8              212.0       5200.0
# 343  Gentoo            49.9           16.1              213.0       5400.0
#
#         sex
# 0      MALE
# 1    FEMALE
# 2    FEMALE
# 4    FEMALE
# ...

# %%
from sklearn.impute import SimpleImputer
