# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv("knn_classification_dataset.csv")

# %%
df
# Out:
#      Age  Estimated Salary  Purchased
# 0     56             45342          0
# 1     46             57157          1
# 2     32             87863          1
# 3     25             72083          0
# 4     38             85733          1
# ..   ...               ...        ...
# 195   23             75609          0
# 196   49            116825          1
# 197   21             76661          0
# 198   28             51024          0
# 199   34             90313          1
#
# [200 rows x 3 columns]

# %%
df.isnull().sum()
# Out:
# Age                 0
# Estimated Salary    0
# Purchased           0
# dtype: int64

# %%
x=df.iloc[:,:-1]
y=df["Purchased"]

# %%
sns.scatterplot(x="Age",y="Estimated Salary",data=df,hue="Purchased")
plt.show()

# %%
from sklearn.preprocessing import StandardScaler

# %%
sc=StandardScaler()
sc.fit(x,y)
# Out:
# StandardScaler()

# %%
x=pd.DataFrame(sc.transform(x),columns=x.columns)

# %% [markdown]
# # how to find nearth value using for loop

# %%
for i in range(1,30):
    knn1=KNeighborsClassifier(n_neighbors=i)
    knn1.fit(x_train,y_train)
    print(i,knn1.score(x_train,y_train)*100,knn1.score(x_test,y_test)*100)
# Out:
# 1 100.0 97.5
# 2 98.125 90.0
# 3 98.75 97.5
# 4 97.5 97.5
# 5 98.75 100.0
# 6 97.5 95.0
# 7 96.875 97.5
# 8 97.5 95.0
# 9 96.875 95.0
# 10 98.75 95.0
# 11 96.875 95.0
# 12 96.875 95.0
# 13 96.25 95.0
# 14 97.5 95.0
# 15 95.625 95.0
# 16 96.875 95.0
# 17 96.25 95.0
# 18 97.5 95.0
# 19 96.875 95.0
# 20 97.5 95.0
# 21 96.875 95.0
# 22 96.875 95.0
# 23 95.625 95.0
# 24 96.25 95.0
# 25 96.25 95.0
# 26 96.25 95.0
# 27 96.25 95.0
# 28 96.875 95.0
# 29 95.625 95.0

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=42)

# %%
from sklearn.neighbors import KNeighborsClassifier

# %%
knn=KNeighborsClassifier(n_neighbors=5)

# %%
knn.fit(x_train,y_train)
# Out:
# KNeighborsClassifier()

# %%
knn.score(x_train,y_train)*100
# Out:
# 98.75

# %%
knn.score(x_test,y_test)*100
# Out:
# 100.0

# %% [markdown]
# # model is not over fitted because on train and test accuracy is same on testing data also

# %% [markdown]
# # overfitting check acc for train but check for testing data must be

# %%
from mlxtend.plotting import plot_decision_regions

# %%
plot_decision_regions(x.to_numpy(),y.to_numpy(),clf=knn)
plt.show()
# Out:
# C:\Users\ansar\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but KNeighborsClassifier was fitted with feature names
#   warnings.warn(

# %%
x
# Out:
#           Age  Estimated Salary
# 0    1.378737         -0.767410
# 1    0.583388         -0.361878
# 2   -0.530100          0.692060
# 3   -1.086844          0.150435
# 4   -0.052891          0.618951
# ..        ...               ...
# 195 -1.245914          0.271459
# 196  0.821993          1.686137
# 197 -1.404984          0.307568
# 198 -0.848240         -0.572384
# 199 -0.371030          0.776152
#
# [200 rows x 2 columns]
