# %% [markdown]
# # dt=DecisionTreeClassifier(max-depth=any depth) thats is prepurning

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv("pruned_social_media_dataset.csv")
df
# Out:
#      age  estimated_salary  purchased
# 0     56             59790          1
# 1     46            127455          1
# 2     32             25600          0
# 3     25            114660          0
# 4     38            113179          1
# ..   ...               ...        ...
# 295   51            109588          1
# 296   38             58513          1
# 297   47             46092          1
# 298   50             31338          0
# 299   45             20412          0
#
# [300 rows x 3 columns]

# %%
df.isnull().sum()
# Out:
# age                 0
# estimated_salary    0
# purchased           0
# dtype: int64

# %%
x=df.iloc[:,:-1]
y=df["purchased"]

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=42)

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
dt=DecisionTreeClassifier(criterion="entropy",max_depth=3) #prepurining

# %%
dt.fit(x_train,y_train)
# Out:
# DecisionTreeClassifier(criterion='entropy', max_depth=3)

# %% [markdown]
# # check first model get overfitted or not

# %% [markdown]
# # pruning is done when model get over fitted

# %%
print("Check accuracy between testing dataset and training data if high diff then it is overfitted::",dt.score(x_train,y_train)*100)
# Out:
# Check accuracy between testing dataset and training data if high diff then it is overfitted:: 92.08333333333333

# %%
print("Check accuracy between testing dataset and training data if high diff then it is overfitted::",dt.score(x_test,y_test)*100)
# Out:
# Check accuracy between testing dataset and training data if high diff then it is overfitted:: 91.66666666666666

# %% [markdown]
# # on training  dataset model accuracy is 100 percent  but on testing dataset model will not capeable to much accurate as trained perform that is model get overfitted we need to pruning it

# %%
from mlxtend.plotting import plot_decision_regions

# %%
plot_decision_regions(x.to_numpy(),y.to_numpy(),clf=dt)
plt.show()
# Out:
# C:\Users\ansar\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
#   warnings.warn(

# %%
from sklearn.tree import plot_tree

# %%
plot_tree(dt)
plt.show()

# %%
# Out:
# 240
