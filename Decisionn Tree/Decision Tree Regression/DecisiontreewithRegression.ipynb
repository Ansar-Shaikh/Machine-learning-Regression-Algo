# %% [markdown]
# # This result indicates that the model is overfitting the training data. Here's what it means:
#
# # High Training Score (87%):
#
# # The model has learned the training data very well.
#  # It may have memorized the patterns instead of generalizing.
# # Negative Test Score (-78%):
#
# # A negative test score (likely R² score in regression) means the model performs worse than a simple mean prediction.
# # The model is failing badly on unseen data.
# # Indicates poor generalization.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv("decision_tree_dataset.csv")

# %%
df
# Out:
#      age  experience  salary
# 0     56          36  164071
# 1     46          11   75318
# 2     32          12  151886
# 3     25          22  135033
# 4     38          24   96077
# ..   ...         ...     ...
# 495   56          10  184202
# 496   49           9  117624
# 497   41          39  177364
# 498   40          37  131785
# 499   49           5  106206
#
# [500 rows x 3 columns]

# %%
df.shape
# Out:
# (500, 3)

# %%
sns.pairplot(df)
plt.show()

# %%
x=df.iloc[:,:-1]
y=df["salary"]

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=42)

# %%
from sklearn.tree import DecisionTreeRegressor,plot_tree

# %%
dt=DecisionTreeRegressor(max_depth=5)

# %%
dt.fit(x_train,y_train)
# Out:
# DecisionTreeRegressor(max_depth=5)

# %%
dt.score(x_train,y_train)*100
# Out:
# 10.729066852348934

# %%
dt.score(x_test,y_test)*100
# Out:
# -0.28394405116671795

# %%
plt.figure(figsize=(10,5))
plot_tree(dt)
plt.show()
