# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_excel("placement1.xlsx")

# %%
df
# Out:
#         cgpa     score  placed
# 0   1.115762  4.599958       0
# 1   5.132483  7.265857       1
# 2   6.800024  7.339405       1
# 3   6.032848  3.535988       1
# 4   4.705103  8.653817       1
# ..       ...       ...     ...
# 94  5.268806  7.660435       1
# 95  5.032482  9.185823       0
# 96  1.271625  1.241968       0
# 97  1.998591  5.302265       1
# 98  3.323799  3.644919       0
#
# [99 rows x 3 columns]

# %%
x=df.iloc[:,:-1]
y=df["placed"]

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=42)

# %%
from sklearn.linear_model import  LogisticRegression

# %%
lr=LogisticRegression()

# %%
lr.fit(x_train,y_train)
# Out:
# LogisticRegression()

# %%
print("accuracy of model :",lr.score(x_test,y_test)*100)
# Out:
# accuracy of model : 40.0

# %%
from sklearn.metrics import confusion_matrix,recall_score,f1_score,accuracy_score,precision_score

# %%
confusion_matrix(y_test,lr.predict(x_test))
# Out:
# array([[3, 8],
#        [4, 5]])

# %% [markdown]
#  # always remember that one thing y_test is acutal point

# %%
cf=confusion_matrix(y_test,lr.predict(x_test))

# %%
sns.heatmap(cf,annot=True)
plt.show()

# %%
precision_score(y_test,lr.predict(x_test))*100
# Out:
# np.float64(38.46153846153847)

# %%
recall_score(y_test,lr.predict(x_test))*100
# Out:
# np.float64(55.55555555555556)

# %%
f1_score(y_test,lr.predict(x_test))*100
# Out:
# np.float64(45.45454545454545)

# %% [markdown]
# # we prefer recall that is high value
