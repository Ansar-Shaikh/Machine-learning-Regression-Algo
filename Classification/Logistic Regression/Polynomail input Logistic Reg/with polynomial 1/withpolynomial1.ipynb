# %%
import pandas as pd
import seaborn as sns 
import matplotlib.pyplot as plt

# %%
df=pd.read_csv("polynomial_dataset.csv")

# %%
df
# Out:
#        data1     data2  output
# 0   1.819461 -1.327324       1
# 1   0.951588  0.148587       1
# 2   0.217416 -0.175408       0
# 3   0.446883  1.163113       1
# 4  -0.321600 -0.447255       0
# ..       ...       ...     ...
# 95  1.009498 -1.048749       0
# 96  1.166316  0.282392       1
# 97  1.158473 -0.357327       0
# 98 -1.635176  1.409743       1
# 99 -0.022319  1.026357       1
#
# [100 rows x 3 columns]

# %%
sns.scatterplot(x="data1",y="data2",data=df,hue="output")
plt.legend(loc=1)
plt.show()

# %%
x=df.iloc[:,:-1]
y=df["output"]

# %%
from sklearn.preprocessing import PolynomialFeatures
pf=PolynomialFeatures(degree=2)
pf.fit(x)
x=pd.DataFrame(pf.transform(x))

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=42)

# %%
from sklearn.linear_model import LogisticRegression

# %%
x.shape
# Out:
# (100, 6)

# %%
lr=LogisticRegression()
lr.fit(x_train,y_train)
# Out:
# LogisticRegression()

# %%
print("accuray of model",lr.score(x_test,y_test)*100)
# Out:
# accuray of model 95.0
