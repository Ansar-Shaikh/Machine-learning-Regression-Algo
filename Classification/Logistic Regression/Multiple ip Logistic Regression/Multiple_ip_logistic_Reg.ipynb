# %% [markdown]
# # if data having multiple input having linear separable data prefer Logistic Regression

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns 
import numpy as np

# %%
df=pd.read_excel("placement.xlsx")
df
# Out:
#         cgpa     score  placed
# 0   1.115762  4.599958       0
# 1   5.132483  7.265857       1
# 2   6.800024  7.339405       1
# 3   6.032848  3.535988       1
# 4   4.705103  8.653817       1
# ..       ...       ...     ...
# 94  5.268806  7.660435       1
# 95  5.032482  9.185823       0
# 96  1.271625  1.241968       0
# 97  1.998591  5.302265       1
# 98  3.323799  3.644919       0
#
# [99 rows x 3 columns]

# %%
df1=pd.read_csv("linear_separable_dataset.csv")

# %%
df1
# Out:
#         CGPA      Score  Placed
# 0   9.061810  95.703519       1
# 1   9.926071  83.993476       1
# 2   9.597991  90.284689       1
# 3   9.397988  91.848291       1
# 4   8.734028  80.929008       1
# 5   8.733992  92.150897       1
# 6   8.587125  83.410482       1
# 7   9.799264  81.301032       1
# 8   9.401673  98.977711       1
# 9   9.562109  99.312641       1
# 10  8.530877  96.167947       1
# 11  9.954865  86.092275       1
# 12  9.748664  81.953442       1
# 13  8.818509  93.684661       1
# 14  8.772737  88.803050       1
# 15  8.775107  82.440765       1
# 16  8.956363  89.903538       1
# 17  9.287135  80.687770       1
# 18  9.147918  98.186408       1
# 19  8.936844  85.175600       1
# 20  9.417779  93.250446       1
# 21  8.709241  86.234222       1
# 22  8.938217  90.401360       1
# 23  9.049543  90.934206       1
# 24  9.184105  83.697089       1
# 25  7.439169  68.225179       0
# 26  7.050266  69.281759       0
# 27  7.378998  51.851116       0
# ...

# %% [markdown]
# # to check it is linearly separable or not using scatter plot having hue para to filter on the hue para

# %%
sns.scatterplot(x="cgpa",y="score",data=df,hue="placed")
plt.legend(loc=1)
plt.show()

# %% [markdown]
# # it is not linearly separable data haing mixed up data

# %% [markdown]
# # what is linear separable data

# %%
df1
# Out:
#         CGPA      Score  Placed
# 0   9.061810  95.703519       1
# 1   9.926071  83.993476       1
# 2   9.597991  90.284689       1
# 3   9.397988  91.848291       1
# 4   8.734028  80.929008       1
# 5   8.733992  92.150897       1
# 6   8.587125  83.410482       1
# 7   9.799264  81.301032       1
# 8   9.401673  98.977711       1
# 9   9.562109  99.312641       1
# 10  8.530877  96.167947       1
# 11  9.954865  86.092275       1
# 12  9.748664  81.953442       1
# 13  8.818509  93.684661       1
# 14  8.772737  88.803050       1
# 15  8.775107  82.440765       1
# 16  8.956363  89.903538       1
# 17  9.287135  80.687770       1
# 18  9.147918  98.186408       1
# 19  8.936844  85.175600       1
# 20  9.417779  93.250446       1
# 21  8.709241  86.234222       1
# 22  8.938217  90.401360       1
# 23  9.049543  90.934206       1
# 24  9.184105  83.697089       1
# 25  7.439169  68.225179       0
# 26  7.050266  69.281759       0
# 27  7.378998  51.851116       0
# ...

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=42)

# %% [markdown]
# # this could be linear separable data

# %%
x=df1.iloc[:,:-1]
x.ndim
# Out:
# 2

# %%
y=df1["Placed"]

# %%
from sklearn.linear_model import LogisticRegression

# %%
lg=LogisticRegression()
lg.fit(x_train,y_train)
# Out:
# LogisticRegression()

# %%
# to check acc use score

# %%
lg.score(x_test,y_test)*100
# Out:
# 100.0

# %% [markdown]
# # how should eqn build
#  # print("y=m1x1+m2x2+c")

# %%
print("coefficient of line multiple reg",lg.coef_)
print("intercept of line multiple reg",lg.intercept_)
# Out:
# coefficient of line multiple reg [[0.1845842  0.71596776]]
# intercept of line multiple reg [-55.83387483]

# %% [markdown]
# # give user input cgpa=9.43 and score=91 what is ouput using this model

# %%
lg.predict([[9.43,91]])
# Out:
# C:\Users\ansar\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but LogisticRegression was fitted with feature names
#   warnings.warn(
# array([1])

# %% [markdown]
# # yes it is placed ie 1for placement

# %%
sns.scatterplot(x="CGPA",y="Score",data=df1,hue="Placed")

plt.show()

# %% [markdown]
# # to make decision boundry line use mlxtend boundry libary

# %%
# always rem: for decision region x and y should be in array like structure convert it to array or to_numpy()

# %%
from mlxtend.plotting import plot_decision_regions
plot_decision_regions(x.to_numpy(),y.to_numpy(),clf=lg)
plt.savefig("decision boundry on logistic reg.jpg")
plt.show()
# Out:
# C:\Users\ansar\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but LogisticRegression was fitted with feature names
#   warnings.warn(
